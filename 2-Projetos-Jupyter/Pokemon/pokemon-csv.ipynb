# %%
# Analisando dados - Pokemon

# %%
#import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

uri = 'C:/Users/garci/PycharmProjects/Python-projetos-Disco-C-PyCharm/Projetos-Jupyter/Pokemon/Dados/pokemonDF-Robert.xlsx'

dadosDF = pd.read_excel(uri, encoding='iso-8859-1')
# encoding that can be useful: 'iso-8859-1', 'utf-8', 'latin1', 'cp1252'

# %%
# transformando em data frame
df = pd.DataFrame(dadosDF)

# %%
df
# Out:
#        #        Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0      1   Bulbasaur    Grass  Poison    318   45      49       49       65
# 1      2     Ivysaur    Grass  Poison    405   60      62       63       80
# 2      3    Venusaur    Grass  Poison    525   80      82       83      100
# 3      4  Charmander     Fire     NaN    309   39      52       43       60
# 4      5  Charmeleon     Fire     NaN    405   58      64       58       80
# ..   ...         ...      ...     ...    ...  ...     ...      ...      ...
# 146  147     Dratini   Dragon     NaN    300   41      64       45       50
# 147  148   Dragonair   Dragon     NaN    420   61      84       65       70
# 148  149   Dragonite   Dragon  Flying    600   91     134       95      100
# 149  150      Mewtwo  Psychic     NaN    680  106     110       90      154
# 150  151         Mew  Psychic     NaN    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# ...

# %%
df.head()
# Out:
#    #        Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 1  2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 2  3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 3  4  Charmander   Fire     NaN    309  39      52       43       60       50
# 4  5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df.sample(5)
# Out:
#        #        Name  Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 128  129    Magikarp   Water     NaN    200   20      10       55       15
# 38    39  Jigglypuff  Normal   Fairy    270  115      45       20       45
# 94    95        Onix    Rock  Ground    385   35      45      160       30
# 6      7    Squirtle   Water     NaN    314   44      48       65       50
# 93    94      Gengar   Ghost  Poison    500   60      65       60      130
#
#      Sp. Def  Speed  Stage  Legendary
# 128       20     80      1      False
# 38        25     20      1      False
# 94        45     70      1      False
# 6         64     43      1      False
# 93        75    110      3      False

# %%
df.shape
# Out:
# (151, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #          151 non-null    int64
#  1   Name       151 non-null    object
#  2   Type 1     151 non-null    object
#  3   Type 2     67 non-null     object
#  4   Total      151 non-null    int64
#  5   HP         151 non-null    int64
#  6   Attack     151 non-null    int64
#  7   Defense    151 non-null    int64
#  8   Sp. Atk    151 non-null    int64
#  9   Sp. Def    151 non-null    int64
#  10  Speed      151 non-null    int64
#  11  Stage      151 non-null    int64
#  12  Legendary  151 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 14.4+ KB

# %%
dadosDF.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  151.000000  151.00000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000  407.07947   64.211921   72.549669   68.225166   67.139073
# std     43.734045   99.74384   28.590117   26.596162   26.916704   28.534199
# min      1.000000  195.00000   10.000000    5.000000    5.000000   15.000000
# 25%     38.500000  320.00000   45.000000   51.000000   50.000000   45.000000
# 50%     76.000000  405.00000   60.000000   70.000000   65.000000   65.000000
# 75%    113.500000  490.00000   80.000000   90.000000   84.000000   87.500000
# max    151.000000  680.00000  250.000000  134.000000  180.000000  154.000000
#
#           Sp. Def       Speed       Stage
# count  151.000000  151.000000  151.000000
# mean    66.019868   68.933775    1.582781
# std     24.197926   26.746880    0.676832
# min     20.000000   15.000000    1.000000
# 25%     49.000000   46.500000    1.000000
# ...

# %%
# plot scatter Defense vs Attack to different values column Type 1

sns.lmplot(x='Attack', y='Defense', data=df,
          fit_reg=False, #sem linha de regressão 
          hue = 'Type 1') # cor por Tipo 1

plt.plot()
# Out:
# []

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue='Stage')

# %%
sns.lmplot(x='Attack', y='Defense', data=df, fit_reg=False, hue='Legendary')

# %%
# Alguns Pokémon que fogem da média / média de escape

#Max Defense
maxDefense = df['Defense'].max()
df[df['Defense'] == maxDefense]
# Out:
#      Name     Type 1  Type 2   Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 148   149  Dragonite  Dragon  Flying  600      91      134       95      100
#
#      Speed  Stage  Legendary  Unnamed: 12
# 148    100     80          3        False

# %%
# Alguns Pokémon que fogem da média / média de escape

# Max Attack
maxAttack = df['Attack'].max()
df[df['Attack'] == maxAttack]
# Out:
#      Name   Type 1  Type 2 Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 112   113  Chansey  Normal   NaN  450     250        5        5       35
#
#      Speed  Stage  Legendary  Unnamed: 12
# 112    105     50          1        False

# %%
# Pokemon scape media

#MaxSpeed
maxSpeed = df['Speed'].max()
df[df['Speed'] == maxSpeed]
# Out:
#      Name    Type 1 Type 2   Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 143   144  Articuno    Ice  Flying  580      90       85      100       95
#
#      Speed  Stage  Legendary  Unnamed: 12
# 143    125     85          1         True

# %%
#Pokemon scape media

#Max HP
maxHp = df['HP'].max()
df[df['HP'] == maxHp]
# Out:
#      Name  Type 1   Type 2 Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 149   150  Mewtwo  Psychic   NaN  680     106      110       90      154
#
#      Speed  Stage  Legendary  Unnamed: 12
# 149     90    130          1         True

# %%
# Legendary Pokemons

df[df['Legendary'] == True]
# Out:
#      Name      Type 1    Type 2   Total   HP  Attack  Defense  Sp. Atk  \
# 0       1   Bulbasaur     Grass  Poison  318      45       49       49
# 3       4  Charmander      Fire     NaN  309      39       52       43
# 6       7    Squirtle     Water     NaN  314      44       48       65
# 9      10    Caterpie       Bug     NaN  195      45       30       35
# 12     13      Weedle       Bug  Poison  195      40       35       30
# ..    ...         ...       ...     ...  ...     ...      ...      ...
# 144   145      Zapdos  Electric  Flying  580      90       90       85
# 145   146     Moltres      Fire  Flying  580      90      100       90
# 146   147     Dratini    Dragon     NaN  300      41       64       45
# 149   150      Mewtwo   Psychic     NaN  680     106      110       90
# 150   151         Mew   Psychic     NaN  600     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary  Unnamed: 12
# 0         65     65     45          1        False
# ...

# %%
fig, ax = plt.subplots(figsize=(14,5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

sns.countplot(x='Type 1', data=df)
plt.xticks(rotation=-45)
plt.show()

# %%
sns.lmplot(x='Sp. Atk', y='Sp. Def', data=df,fit_reg=False, hue='Type 1')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-7fd7ce2c0601> in <module>
# ----> 1 sns.lmplot(x='Sp. Atk', y='Sp. Def', data=df,fit_reg=False, hue='Type 1')
#
# ~\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     831
# ...

# %%
coluna_hp = dadosDF['HP']
coluna_hp

# %%
coluna_hp_counts = coluna_hp.value_counts()
coluna_hp_counts

# %%
# todos pokemons que tenham HP = 490

colu_hp_490 = dadosDF[dadosDF['HP'] == 490]
colu_hp_490

# %%
dfHP = pd.DataFrame(colu_hp_490)

# %%
dfHP.values

# %%
dadosDF.plot()

# %%
coluna_hp.hist()

# %%
import seaborn as sns

# %%
sns.countplot(coluna_hp)

# %%
sns.countplot(coluna_hp_counts)

# %%
coluna_hp_counts
